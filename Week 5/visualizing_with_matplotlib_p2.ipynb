# %% [markdown]
# # Matplotlib

# %%
# Notebook Magic Line
# create visualizations in the notebook itself
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/PA Projects/ML Class/Week 4/Top_AI_scientists_cleaned.csv")
df
# Out:
#      National Rank  World Rank  ... Citations H-index
# 0                1           1  ...    224608     197
# 1                2           2  ...    403071     185
# 2                1           3  ...    404800     184
# 3                3           4  ...    156845     182
# 4                4           5  ...    211810     180
# ..             ...         ...  ...       ...     ...
# 989             46         996  ...     40875      72
# 990            604         997  ...     38343      72
# 991             36         998  ...     35627      72
# 992             13         999  ...     31530      72
# 993            605        1000  ...     30843      72
#
# [994 rows x 9 columns]

# %% [markdown]
# ## Line Chart

# %%
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
country_cnt = df['Country'].value_counts().to_dict()

countries = list(country_cnt.keys())
cnt = list(country_cnt.values())

plt.rcParams["figure.figsize"] = (15,5)

plt.title("Presence of Countries")

plt.plot(cnt,'g^')

plt.xticks(ticks=range(len(countries)),labels=countries, rotation='vertical')

plt.show()

# %% [markdown]
# ## Bar Plot

# %%
country_cnt = df['Country'].value_counts().to_dict()

countries = list(country_cnt.keys())
cnt = list(country_cnt.values())

plt.rcParams["figure.figsize"] = (20,10)

plt.xticks(ticks=range(len(countries)),labels=countries, rotation='vertical')

plt.bar(countries,cnt,color=['red','blue','green'])

plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.title("#DBLP Distribution")

plt.xlabel('#DBLP')

plt.rcParams["figure.figsize"] = (10,5)

plt.ylabel('Frequency')

plt.hist(df['#DBLP'],bins=50,color='lightblue') # bins define how many ranges should be considered from min to max

plt.show()

# %% [markdown]
# ## Box Plots

# %%
outliers = dict(markerfacecolor = 'r', marker = 'D')
plt.title('#DBLP Distribution')
plt.boxplot(df[['#DBLP']],labels=['#DBLP'],flierprops=outliers)
plt.show()

# %% [markdown]
# ### Multiple blotplot in one

# %%
data = df[['#DBLP','H-index']]
outliers = dict(markerfacecolor = 'g', marker = 'D')
plt.rcParams["figure.figsize"] = (20,10)
fig,ax = plt.subplots()
plt.boxplot(data.values,labels=['#DBLP','H-index'],flierprops=outliers)
plt.show()

# %%
data = df[['#DBLP','H-index','Citations']]
outliers = dict(markerfacecolor = 'b', marker = 'D')
plt.rcParams["figure.figsize"] = (20,10)
fig,ax = plt.subplots()
plt.boxplot(data.values,labels=['#DBLP','H-index','Citations'],flierprops=outliers)
plt.show()

# %% [markdown]
# ## Violin Plots
# shows density distribution

# %%
data = df[['#DBLP','H-index']]

plt.rcParams["figure.figsize"] = (20,10)

fig,ax = plt.subplots()

plt.xticks(ticks=[1,2],labels=['#DBLP','H-index'])

plt.violinplot(data.values)

plt.show()

# %% [markdown]
# ## Scatter Plots
# shows relative distribution of two variables

# %%
plt.xlabel('#DBLP')
plt.ylabel('World Rank')

plt.scatter(df['#DBLP'],df['World Rank'])

# %%
plt.xlabel('Citations')
plt.ylabel('World Rank')

plt.scatter(df['Citations'],df['World Rank'])

# %% [markdown]
# ## Bubble Plots
# relative distribution among 3 variables

# %%
plt.xlabel('Citations')
plt.ylabel('#DBLP')

plt.scatter(df['Citations'][:100],df['#DBLP'][:100],s=df['World Rank'][:100]) # s is the size of the bubble

# %% [markdown]
# Useful Resources for more exploration: <br/>
# i) https://matplotlib.org/stable/gallery/index.html <br/>
# ii) https://www.python-graph-gallery.com
